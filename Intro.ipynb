# %% [markdown]
# ![VU evolving landscapes](./medias/evolving_landscapes.png)
#
# [jhub-link]: https://hub2.compute.vu.nl/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fmatheuswalmeida%2FEvolving-Landscapes-S2S-25%2Fblob%2Fmain%2FREADME.md&urlpath=tree%2FREADME.md%2F&branch=master
# [badge]: https://img.shields.io/badge/Run%20on-EarthscapeHub-orange
#
# Click this button:
#
# [![Run on VU JupyterHub][badge]][jhub-link]
#
# to open the lessons directly on the VU JupyterHub instance!
