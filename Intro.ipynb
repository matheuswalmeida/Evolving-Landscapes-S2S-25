# %% [markdown]
# ![VU evolving landscapes](./medias/evolving_landscapes.png)
#
# [jhub-link]: https://hub1.compute.vu.nl/user/wci440/lab/tree/Evolving_Landscapes_2025/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fmatheuswalmeida%2FEvolving-Landscapes-S2S-25%23&urlpath=tree%2FEvolving-Landscapes-S2S-25%23%2F&branch=master
#
#
#
# [![Run on VU JupyterHub][badge]][jhub-link]
