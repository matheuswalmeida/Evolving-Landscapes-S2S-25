# %% [markdown]
# # Source To Sink 2025
#
#
# ![VU evolving landscapes](./medias/evolving_landscapes.png)
#
# ## Landscape evolution modeling sessions report
#
# ### Instructions
#
# Use this notebook to create a report of the practical exercises you did at our landscape evolution modeling sessions I, II, and III.
#
# 1. Start with a small introduction (based on the previous lectures and the course literature) on **why rivers and hillslopes are important** and **how rivers and hillslopes respond to changes in climate and tectonics**, mentioning how their interactions drive landscape evolution. (150 words max).
#
# 2. Go back to the Rivers, Hillslopes and Landlab notebooks, and you will see selected figures are flagged in their respective notebooks. Paste the selected figures in this report, explain what the figure is showing, what are the processes related to it (e.g. changes in climate, changes in uplift, etc..) and what are the implications in a landscape evolution perspective.
#
# 3. Finish with a small conclusion paragraph bridging the content of the modeling sessions (150 words max).
#
# 4. After finishing the report, you can **export this notebook as a PDF and upload it to Canvas**.
#
# **Important!**: The content of the figures will be evaluated. Make sure to label the axis of every figure, using the correct units.
#
# > **Note 1:** Don't forget to put your names in the report
#
# > **Note 2:** Use markdown cells to write text block and paste the figures you have generated.

# %% [markdown]
# Name:

# %% [markdown]
# ### Introduction

# %% [markdown]
# ...Start your introduction here....

# %% [markdown]
# ### Rivers
#
# ... Start the report on the Rivers notebook here...

# %% [markdown]
# ### Hillslopes
#
# ... Start the report on the Hillslopes notebook here ...

# %% [markdown]
# ### Landlab
#
# ... Start the report on the Introduction to Landlab notebook here...

# %% [markdown]
# ### Conclusions
#
# ... Write your conclusion here ...
